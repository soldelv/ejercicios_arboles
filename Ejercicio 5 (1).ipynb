# %%
import json

# %%
payload1 ={
  "user_case": {
    "bill_data": {},
    "seller_reputation": {
      "metrics": {
        "cancellations": {
          "period": "365 days",
          "rate": 0,
          "value": 0
        },
        "claims": {
          "period": "365 days",
          "rate": 0,
          "value": 0
        },
        "delayed_handling_time": {
          "period": "365 days",
          "rate": 0,
          "value": 0
        },
        "sales": {
          "period": "365 days",
          "completed": 0
        }
      },
      "transactions": {
        "canceled": 0,
        "period": "historic",
        "total": 0,
        "ratings": {
          "negative": 0,
          "neutral": 0,
          "positive": 0
        },
        "completed": 0
      }
    },
    "thumbnail": {
      "picture_url": "https://mla-s1-p.mlstatic.com/942874-MLA45185732644_032021-O.jpg",
      "picture_id": "942874-MLA45185732644_032021"
    },
    "seller_experience": "NEWBIE",
    "private_info": {
      "data": {
        "user": {
          "names": {
            "brand": ""
          },
          "registration_identifiers": {
            "email": {
              "address": "priscilla.alvesr@gmail.com"
            }
          }
        }
      }
    },
    "tags": [
      "normal",
      "credits_profile",
      "messages_as_seller",
      "messages_as_buyer"
    ],
    "points": 2,
    "shipping_modes": [
    ],
    "registration_date": "2019-11-28T17:15:55.000-04:00",
    "user_type": "normal",
    "nickname": "RIPR6135013",
    "site_id": "MLB",
    "context": {
      "source": "mercadopago",
      "device": "mobile-android",
      "flow": "mercadopago"
    },
    "company": {
      "cust_type_id": "CO"
    },
    "id": 421326073,
    "internal_tags": [],
    "secure_email": "prisci.78slpr@mail.mercadolivre.com",
    "permalink": "http://perfil.mercadolivre.com.br/RIPR6135013",
    "credit": {
      "consumed": 0,
      "rank": "newbie"
    },
    "country_id": "BR",
    "status": {
      "shopping_cart": {
        "buy": "allowed",
        "sell": "allowed"
      },
      "immediate_payment": "false",
      "buy": {
        "allow": "true",
        "codes": [],
        "immediate_payment": {
          "reasons": [],
          "required": "false"
        }
      },
      "sell": {
        "allow": "true",
        "codes": [],
        "immediate_payment": {
          "reasons": [],
          "required": "false"
        }
      },
      "mercadopago_account_type": "personal",
      "list": {
        "allow": "false",
        "codes": [
          "address_pending"
        ],
        "immediate_payment": {
          "reasons": [],
          "required": "false"
        }
      },
      "verification_status": "DOK",
      "billing": {
        "allow": "false",
        "codes": [
          "address_pending"
        ]
      },
      "user_type": "complete_registration",
      "mercadoenvios": "not_accepted",
      "site_status": "active",
      "mercadopago_tc_accepted": "true",
      "confirmed_email": "false"
    }
  },
  "multiples_ids": "false",
  "operations": [],
  "comments": "User não recebeu o valor por indicação \n\nCupom aplicado corretamente\n727401553 - conta da pessoa que recebeu a indicação \n421326073 - conta da pessoa que indicou \n14050337610 - 1 pagamento \n",
  "form": {
    "form": {
      "Invite_ID": "421326073",
      "payment_id": "14050337610",
      "error_description": "User não recebeu o valor por indicação\n\nCupom aplicado corretamente\n727401553 - conta da pessoa que recebeu a indicação\n421326073 - conta da pessoa que indicou\n14050337610 - 1 pagamento\n",
      "Booster_ID": "727401553",
      "Link_da_indica_o_MGM": "0",
      "campaign_id": "0"
    },
    "template_last_modification": "2021-01-26T15:35:24Z",
    "case_id": 100101280,
    "created_at": "2021-03-15T10:19:06.600-0400",
    "template_id": 741,
    "derivation_id": 21025064,
    "created_by": "ext_edaianem"
  },
  "id": "669278112981",
  "type": "active",
  "request_id": "0b4de12e-b6c0-4395-b901-3919f553cfaa",
  "case": {
    "last_outgoing_date": "2021-03-15T10:19:06.838-0400",
    "process_id": 719,
    "portal_status": "WAITING_FOR_EXTERNAL",
    "origin": "SUPPORT_WIDGET_MP_MOBILE",
    "channel": "CHAT",
    "survey_sent": "false",
    "problem_id": 758,
    "last_modification_date": "2021-03-15T09:59:45.000-0400",
    "details": {
      "touched": "true",
      "last_response_derivation": 1048,
      "last_derivation_rule": 5184,
      "Problem_Type__c": "None",
      "last_consult_derivation_reason": 2633,
      "Channel_Queue__c": "MLB_Seg360",
      "last_queue": 1048,
      "last_response_derivation_reason": 2053,
      "case_creation_date": "2021-03-15T09:59:45.386-04:00",
      "last_derivation_option": 113,
      "last_consult_derivation": 124
    },
    "id": 100101280,
    "queue_id": 124,
    "user_subject": "",
    "last_incoming_date": "2021-03-15T10:19:06.901-0400",
    "date_created": "2021-03-15T09:59:45.000-0400",
    "type_id": 3,
    "form_id": 1,
    "user_segment": "LOYAL_BUYER_3",
    "current_channel": "OFFLINE",
    "is_reprocess": "false",
    "user_id": 421326073,
    "entities": {},
    "origin_detail": "WebChat",
    "site_id": "MLB",
    "source_id": 1615,
    "faq_id": 15903,
    "status": "OPENED",
    "last_derivation_date": "2021-03-15T10:19:06.058-0400",
    "gin_expiration_date": "2021-03-18T10:19:06.058-0400"
  },
  "discarded_ids": {
    "payment": [
      "14050337610"
    ]
  }
}

# %%
payload2={
  "user_case": {
    "bill_data": {},
    "seller_reputation": {
      "metrics": {
        "cancellations": {
          "period": "60 months",
          "rate": 0,
          "value": 0
        },
        "claims": {
          "period": "60 months",
          "rate": 0,
          "value": 0
        },
        "delayed_handling_time": {
          "period": "60 months",
          "rate": 0,
          "value": 0
        },
        "sales": {
          "period": "60 months",
          "completed": 0
        }
      },
      "transactions": {
        "canceled": 0,
        "period": "historic",
        "total": 0,
        "ratings": {
          "negative": 0,
          "neutral": 0,
          "positive": 0
        },
        "completed": 0
      }
    },
    "seller_experience": "NEWBIE",
    "private_info": {
      "data": {
        "user": {
          "names": {
            "brand": ""
          },
          "registration_identifiers": {
            "email": {
              "address": "a_valim@hotmail.com"
            }
          }
        }
      }
    },
    "tags": [
      "normal",
      "credits_priority_2",
      "credits_profile",
      "messages_as_buyer"
    ],
    "points": 11,
    "shipping_modes": [
      "custom",
      "not_specified"
    ],
    "registration_date": "2016-11-24T15:34:46.000-04:00",
    "user_type": "normal",
    "nickname": "ANDRVALIMDOSSANTOS",
    "site_id": "MLB",
    "context": {
      "source": "buflo",
      "device": "web-mobile",
      "flow": "buy"
    },
    "company": {
      "cust_type_id": "CO"
    },
    "id": 235620344,
    "internal_tags": [],
    "secure_email": "avalimd.schb58@mail.mercadolivre.com",
    "permalink": "http://perfil.mercadolivre.com.br/ANDRVALIMDOSSANTOS",
    "credit": {
      "consumed": 0,
      "rank": "newbie"
    },
    "country_id": "BR",
    "status": {
      "shopping_cart": {
        "buy": "allowed",
        "sell": "allowed"
      },
      "immediate_payment": "false",
      "buy": {
        "allow": "true",
        "codes": [],
        "immediate_payment": {
          "reasons": [],
          "required": "false"
        }
      },
      "sell": {
        "allow": "true",
        "codes": [],
        "immediate_payment": {
          "reasons": [],
          "required": "false"
        }
      },
      "mercadopago_account_type": "personal",
      "list": {
        "allow": "false",
        "codes": [
          "address_pending",
          "address_empty_city",
          "address_empty_state"
        ],
        "immediate_payment": {
          "reasons": [],
          "required": "false"
        }
      },
      "verification_status": "DM",
      "billing": {
        "allow": "false",
        "codes": [
          "address_pending",
          "address_empty_city",
          "address_empty_state"
        ]
      },
      "user_type": "complete_registration",
      "mercadoenvios": "not_accepted",
      "site_status": "active",
      "mercadopago_tc_accepted": "true",
      "confirmed_email": "false"
    }
  },
  "multiples_ids": "false",
  "operations": [
    {
      "payment": [
        {
          "metadata": {},
          "operation_type": "regular_payment",
          "point_of_interaction": {},
          "fee_details": [],
          "date_approved": "2021-03-12T11:35:19.000-04:00",
          "payer": {
            "identification": {
              "number": "15631557886",
              "type": "CPF"
            },
            "phone": {
              "number": "11948380426",
              "area_code": " "
            },
            "last_name": "Valim dos Santos",
            "id": "235620344",
            "type": "registered",
            "first_name": "André",
            "email": "a_valim@hotmail.com"
          },
          "client_id": "1311377052931992",
          "transaction_details": {
            "total_paid_amount": 116.41,
            "installment_amount": 0,
            "net_received_amount": 116.41,
            "overpaid_amount": 0
          },
          "payer_tags": [],
          "installments": 1,
          "product_id": "BCKJO2VHAU10018OVCE0",
          "reserve_id": "1650195669",
          "charges_details": [],
          "id": 14021146365,
          "payment_type_id": "account_money",
          "order": {},
          "marketplace": "NONE",
          "available_actions": [
            "refund"
          ],
          "application_id": 1311377052931992,
          "version": 1,
          "status_detail": "accredited",
          "additional_info": {
            "tracking_id": "platform:v1-blacklabel,so:ALL,type:N/A,security:2fa"
          },
          "live_mode": "true",
          "site_id": "MLB",
          "payer_id": 235620344,
          "card": {},
          "status": "approved",
          "transaction_amount_refunded": 0,
          "transaction_amount": 116.41,
          "description": "Pagamento do servico (Banco do Brasil S.A.)",
          "collector_tags": [],
          "money_release_date": "2021-03-12T11:35:19.000-04:00",
          "collector": {
            "identification": {
              "number": "68900810000138",
              "type": "CNPJ"
            },
            "phone": {},
            "last_name": ".-",
            "id": 486005861,
            "first_name": "MP PGTO CONTAS",
            "email": "bancorendimiento@hotmail.com"
          },
          "refunds": [],
          "captured": "true",
          "collector_id": 486005861,
          "taxes_amount": 0,
          "internal_metadata": {
            "rule_engine": {
              "valid_promise": "false",
              "with_promise": "false",
              "rules": [
                {
                  "rule_id": 21000231962,
                  "rule_set": "financing_fee_collector"
                },
                {
                  "rule_id": 21000005979,
                  "rule_set": "processing_fee_and_release"
                }
              ]
            },
            "internal_risk_analysis": "by_risk",
            "capture_mode": "total",
            "utility": {
              "category_id": "bank",
              "scope": "",
              "id": "565812077",
              "entity_id": "001",
              "barcode": "00199856400000116410000003304249007240803917",
              "version": "2",
              "drawee_document": "000015631557886"
            },
            "type": "utility"
          },
          "risk_execution_id": 500474693511,
          "date_last_updated": "2021-03-12T11:35:19.000-04:00",
          "coupon_amount": 0,
          "contingencies": {
            "list": [],
            "status": "none"
          },
          "date_created": "2021-03-12T11:35:18.000-04:00",
          "money_release_days": 0,
          "acquirer_reconciliation": [],
          "api_version": "2",
          "shipping_amount": 0,
          "payment_method_id": "account_money",
          "binary_mode": "true",
          "processing_mode": "aggregator",
          "currency_id": "BRL"
        }
      ]
    }
  ],
  "comments": "User não recebeu desconto em pagamento de serviço que fez de conta de luz, podem verificar?\n\nPagamento #14021146365\nID vendedor >> 486005861\nCampanha >> 1258383\n\nSamsung A30\nVersão 2.159.3\n\nComprovante em anexo>>",
  "form": {
    "form": {
      "payment_id": "14021146365",
      "error_description": "User não recebeu desconto em pagamento de serviço que fez de conta de luz, podem verificar?",
      "attach_file": "https://v2-cx-one.adminml.com/files/limryi-210315122220_01.PNG",
      "campaign_id": "486005861",
      "error_classification": "Outros descontos"
    },
    "template_last_modification": "2021-01-26T15:35:24Z",
    "case_id": 100081571,
    "created_at": "2021-03-15T08:22:21.567-0400",
    "template_id": 741,
    "derivation_id": 21015587,
    "created_by": "ext_palisand"
  },
  "id": "669278112981",
  "type": "active",
  "request_id": "13120b13-48cb-4985-b3cf-7e0ced34da79",
  "case": {
    "last_outgoing_date": "2021-03-15T08:22:21.731-0400",
    "process_id": 719,
    "portal_status": "WAITING_FOR_EXTERNAL",
    "origin": "SUPPORT_WIDGET_MP_MOBILE",
    "channel": "CHAT",
    "survey_sent": "false",
    "problem_id": 771,
    "last_modification_date": "2021-03-15T08:21:35.000-0400",
    "details": {
      "touched": "true",
      "last_derivation_rule": 5184,
      "Problem_Type__c": "None",
      "last_consult_derivation_reason": 2633,
      "Channel_Queue__c": "MLB_Payers_L12",
      "last_queue": 1048,
      "case_creation_date": "2021-03-15T08:12:29.517-04:00",
      "last_derivation_option": 113,
      "last_consult_derivation": 124
    },
    "id": 100081571,
    "queue_id": 124,
    "user_subject": "",
    "last_incoming_date": "2021-03-15T08:22:21.794-0400",
    "date_created": "2021-03-15T08:12:29.000-0400",
    "type_id": 3,
    "form_id": 1,
    "user_segment": "LOYAL_BUYER_2",
    "current_channel": "OFFLINE",
    "is_reprocess": "false",
    "user_id": 235620344,
    "entities": {
      "payment_id": 14021146365
    },
    "origin_detail": "WebChat",
    "site_id": "MLB",
    "source_id": 1615,
    "faq_id": 15897,
    "status": "OPENED",
    "last_derivation_date": "2021-03-15T08:22:21.270-0400",
    "gin_expiration_date": "2021-03-18T08:22:21.270-0400"
  },
  "discarded_ids": {}
}

# %%
def get_payment(payload):
    payment_id =0
    
    for i in payload.get('operations',{}): 
        for k in i.get('payment',{}):
            payment_id =k.get('id')
    
    return payment_id

# %%
get_payment(payload1)
# Out:
# 0

# %%
get_payment(payload2)
# Out:
# 14021146365

# %% [markdown]
# Los payloads son los brindados por el ejercicios, tomados desde los links
# Payload completo: https://drive.google.com/file/d/1Hs85zNFDOnKpbsrMHZzSdxXFoBth_HrY/view?usp=sharing (payload2)
# Payload incompleto: https://drive.google.com/file/d/1XYhdBpOXeJBimi4e7WaElxWJAzUUH6Om/view?usp=sharing (payload1)
